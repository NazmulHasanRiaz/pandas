# %%
import pandas as pd

# %%
covid = r'C:\Users\Riaz\Desktop\pandas\Covid_19.csv'
covid = pd.read_csv(covid)
covid
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020       NaN     Afghanistan       1939      60        252
# 1    4/29/2020       NaN         Albania        766      30        455
# 2    4/29/2020       NaN         Algeria       3848     444       1702
# 3    4/29/2020       NaN         Andorra        743      42        423
# 4    4/29/2020       NaN          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [321 rows x 6 columns]

# %%
covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 321 entries, 0 to 320
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       321 non-null    object
#  1   State      140 non-null    object
#  2   Region     321 non-null    object
#  3   Confirmed  321 non-null    int64
#  4   Deaths     321 non-null    int64
#  5   Recovered  321 non-null    int64
# dtypes: int64(3), object(3)
# memory usage: 15.2+ KB

# %%
covid.shape
# Out:
# (321, 6)

# %%
covid.count()
# Out:
# Date         321
# State        140
# Region       321
# Confirmed    321
# Deaths       321
# Recovered    321
# dtype: int64

# %% [markdown]
# ### finding null values...

# %%
Covid.isnull().sum()
# Out:
# Date               0
# State             50
# Region             0
# Confirmed          0
# Deaths             0
# Recovered          0
# percent            0
# Deaths_percent     0
# dtype: int64

# %%
covid['State'].dtype
# Out:
# dtype('O')

# %%
covid['Region'].value_counts()
# Out:
# US                          58
# Mainland China              31
# Canada                      15
# France                      11
# UK                          11
#                             ..
# Peru                         1
# Central African Republic     1
# Croatia                      1
# Norway                       1
# Philippines                  1
# Name: Region, Length: 187, dtype: int64

# %% [markdown]
# ### Show the number of confirmed, Death, Recovered in each region

# %%
covid.groupby('Region').sum()
# Out:
#                     Confirmed  Deaths  Recovered
# Region
# Afghanistan              1939      60        252
# Albania                   766      30        455
# Algeria                  3848     444       1702
# Andorra                   743      42        423
# Angola                     27       2          7
# ...                       ...     ...        ...
# West Bank and Gaza        344       2         71
# Western Sahara              6       0          5
# Yemen                       6       0          1
# Zambia                     97       3         54
# Zimbabwe                   32       4          5
#
# [187 rows x 3 columns]

# %% [markdown]
# ### showing the case where confirmed case is less than 10...

# %%
covid[covid['Confirmed']<10].sort_values('Confirmed',ascending = True)
# Out:
#           Date                             State                 Region  \
# 285  4/29/2020                         Recovered                     US
# 284  4/29/2020                         Recovered                 Canada
# 203  4/29/2020      Diamond Princess cruise ship                 Canada
# 305  4/29/2020                             Tibet         Mainland China
# 289  4/29/2020         Saint Pierre and Miquelon                 France
# 184  4/29/2020                          Anguilla                     UK
# 272  4/29/2020             Northwest Territories                 Canada
# 192  4/29/2020  Bonaire, Sint Eustatius and Saba            Netherlands
# 177  4/29/2020                               NaN         Western Sahara
# 194  4/29/2020            British Virgin Islands                     UK
# 288  4/29/2020                  Saint Barthelemy                 France
# 178  4/29/2020                               NaN                  Yemen
# ...

# %% [markdown]
# ### Deleting the case where confirmed case is less than 10

# %%
Covid =covid[~covid['Confirmed']<10].head(50)

# %%
Covid
# Out:
#          Date State                    Region  Confirmed  Deaths  Recovered
# 0   4/29/2020   NaN               Afghanistan       1939      60        252
# 1   4/29/2020   NaN                   Albania        766      30        455
# 2   4/29/2020   NaN                   Algeria       3848     444       1702
# 3   4/29/2020   NaN                   Andorra        743      42        423
# 4   4/29/2020   NaN                    Angola         27       2          7
# 5   4/29/2020   NaN       Antigua and Barbuda         24       3         11
# 6   4/29/2020   NaN                 Argentina       4285     214       1192
# 7   4/29/2020   NaN                   Armenia       1932      30        900
# 8   4/29/2020   NaN                   Austria      15402     580      12779
# 9   4/29/2020   NaN                Azerbaijan       1766      23       1267
# 10  4/29/2020   NaN                   Bahamas         80      11         23
# ...

# %% [markdown]
# ### In which Region max number of Death cases were found...

# %%
Covid.groupby('Region')['Deaths'].sum().sort_values(ascending = False)
# Out:
# Region
# Belgium                     7501
# Brazil                      5513
# Ecuador                      883
# Austria                      580
# Algeria                      444
# Denmark                      443
# Egypt                        380
# Dominican Republic           293
# Colombia                     278
# Czech Republic               227
# Chile                        216
# Argentina                    214
# Bangladesh                   163
# Belarus                       84
# Croatia                       67
# Bosnia and Herzegovina        65
# Bulgaria                      64
# Cameroon                      61
# Afghanistan                   60
# Bolivia                       59
# Cuba                          58
# Burkina Faso                  43
# Andorra                       42
# Congo (Kinshasa)              30
# Albania                       30
# Armenia                       30
# Azerbaijan                    23
# Cyprus                        15
# ...

# %%
Covid['Deaths'].value_counts(normalize = True) * 100
# Out:
# 1       10.0
# 0        8.0
# 2        8.0
# 30       6.0
# 6        4.0
# 8        4.0
# 883      2.0
# 293      2.0
# 67       2.0
# 42       2.0
# 65       2.0
# 444      2.0
# 9        2.0
# 580      2.0
# 163      2.0
# 13       2.0
# 380      2.0
# 58       2.0
# 59       2.0
# 60       2.0
# 43       2.0
# 64       2.0
# 443      2.0
# 3        2.0
# 278      2.0
# 227      2.0
# 216      2.0
# 23       2.0
# 214      2.0
# 84       2.0
# 15       2.0
# 7501     2.0
# 11       2.0
# 5513     2.0
# 7        2.0
# 61       2.0
# Name: Deaths, dtype: float64

# %% [markdown]
# ### Get percentage values on the basis of Deaths...

# %%
Covid['Deaths_percent'] = (Covid['Deaths'] / 
                  Covid['Deaths'].sum()) * 100

# %%
Covid
# Out:
#          Date State                    Region  Confirmed  Deaths  Recovered  \
# 0   4/29/2020   NaN               Afghanistan       1939      60        252
# 1   4/29/2020   NaN                   Albania        766      30        455
# 2   4/29/2020   NaN                   Algeria       3848     444       1702
# 3   4/29/2020   NaN                   Andorra        743      42        423
# 4   4/29/2020   NaN                    Angola         27       2          7
# 5   4/29/2020   NaN       Antigua and Barbuda         24       3         11
# 6   4/29/2020   NaN                 Argentina       4285     214       1192
# 7   4/29/2020   NaN                   Armenia       1932      30        900
# 8   4/29/2020   NaN                   Austria      15402     580      12779
# 9   4/29/2020   NaN                Azerbaijan       1766      23       1267
# 10  4/29/2020   NaN                   Bahamas         80      11         23
# ...

# %% [markdown]
# ### Sorting the entire Dataframe w.r.t Confirmed

# %%
Covid.sort_values('Confirmed', ascending = True)
# Out:
#          Date State                    Region  Confirmed  Deaths  Recovered  \
# 18  4/29/2020   NaN                    Bhutan          7       0          5
# 27  4/29/2020   NaN                   Burundi         11       1          4
# 45  4/29/2020   NaN                  Dominica         16       0         13
# 16  4/29/2020   NaN                    Belize         18       2          9
# 21  4/29/2020   NaN                  Botswana         23       1          5
# 5   4/29/2020   NaN       Antigua and Barbuda         24       3         11
# 4   4/29/2020   NaN                    Angola         27       2          7
# 31  4/29/2020   NaN  Central African Republic         50       0         10
# 32  4/29/2020   NaN                      Chad         52       2         19
# 17  4/29/2020   NaN                     Benin         64       1         33
# 13  4/29/2020   NaN                  Barbados         80       7         39
# ...
