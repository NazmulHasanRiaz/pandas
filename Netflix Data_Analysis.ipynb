# %%
import pandas as pd

# %%
netflix = r'C:\Users\Riaz\Desktop\pandas\Netflix Dataset.csv'
netflix = pd.read_csv(netflix)
netflix
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   object
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
# dtypes: object(11)
# memory usage: 669.5+ KB

# %%
netflix.columns
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %% [markdown]
# ### 1.Find duplicate & remove ...

# %%
netflix[netflix.duplicated()]
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date Rating Duration  \
# 6300      April 5, 2019  TV-MA   97 min
# 6622  September 4, 2020  TV-MA   94 min
#
#                                        Type  \
# 6300  Dramas, Independent Movies, Thrillers
# 6622   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %%
netflix.drop_duplicates(inplace=True)

# %%
netflix
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %% [markdown]
# ### 2.Finding null values...

# %%
netflix.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
import seaborn as sns

# %%
sns.heatmap(netflix.isnull())
# Out:
# <AxesSubplot:>

# %%
netflix.dropna(subset=['Director','Cast','Country','Release_Date','Rating'], how='any',inplace=True)

# %%
netflix
# Out:
#      Show_Id Category       Title           Director  \
# 1         s2    Movie       07:19  Jorge Michel Grau
# 2         s3    Movie       23:59       Gilbert Chan
# 3         s4    Movie           9        Shane Acker
# 4         s5    Movie          21     Robert Luketic
# 5         s6  TV Show          46        Serdar Akar
# ...      ...      ...         ...                ...
# 7780   s7779    Movie  Zombieland    Ruben Fleischer
# 7782   s7781    Movie         Zoo       Shlok Sharma
# 7783   s7782    Movie        Zoom       Peter Hewitt
# 7784   s7783    Movie        Zozo        Josef Fares
# 7785   s7784    Movie      Zubaan        Mozez Singh
#
#                                                    Cast  \
# 1     Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 2     Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 3     Elijah Wood, John C. Reilly, Jennifer Connelly...
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...

# %% [markdown]
# ### Getting particular element in a dataset...

# %% [markdown]
# ### 3. for 'Zubaan' what is the show id & who is the director

# %%
netflix[netflix['Title'].str.contains('Zubaan')]
# Out:
#      Show_Id Category   Title     Director  \
# 7785   s7784    Movie  Zubaan  Mozez Singh
#
#                                                    Cast Country  \
# 7785  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...   India
#
#        Release_Date Rating Duration  \
# 7785  March 2, 2019  TV-14  111 min
#
#                                                 Type  \
# 7785  Dramas, International Movies, Music & Musicals
#
#                                             Description
# 7785  A scrappy but poor boy worms his way into a ty...

# %% [markdown]
# ### 4.In which year highest nummber of movies & tv shows were realesed...

# %%
netflix['Date'] = pd.to_datetime(netflix['Release_Date'])

# %%
netflix.head()
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
# 5      s6  TV Show     46        Serdar Akar
#
#                                                 Cast        Country  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# 5  Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...         Turkey
#
#         Release_Date Rating  Duration  \
# 1  December 23, 2016  TV-MA    93 min
# 2  December 20, 2018      R    78 min
# 3  November 16, 2017  PG-13    80 min
# 4    January 1, 2020  PG-13   123 min
# 5       July 1, 2017  TV-MA  1 Season
#
# ...

# %%
netflix['Date'].dt.year.value_counts()
# Out:
# 2019    1337
# 2020    1229
# 2018    1115
# 2017     752
# 2016     207
# 2021      78
# 2015      50
# 2014      14
# 2011      13
# 2013       7
# 2012       3
# 2009       2
# 2008       1
# 2010       1
# Name: Date, dtype: int64

# %%
netflix['Date'].dt.year.value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### 5. How many Movies & Tv shows in data set...

# %%
netflix['Category'].value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
netflix.groupby('Category').Category.count().plot(kind = 'pie')
# Out:
# <AxesSubplot:ylabel='Category'>

# %% [markdown]
# ### 5. Show all the Tv Shows were realsed in 2017..

# %%
netflix['Year'] = netflix['Date'].dt.year

# %%
netflix.head()
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
# 5      s6  TV Show     46        Serdar Akar
#
#                                                 Cast        Country  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# 5  Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...         Turkey
#
#         Release_Date Rating  Duration  \
# 1  December 23, 2016  TV-MA    93 min
# 2  December 20, 2018      R    78 min
# 3  November 16, 2017  PG-13    80 min
# 4    January 1, 2020  PG-13   123 min
# 5       July 1, 2017  TV-MA  1 Season
#
# ...

# %%
netflix[(netflix['Category']=='TV Show') & (netflix['Year']== 2017)]
# Out:
#      Show_Id Category                                             Title  \
# 5         s6  TV Show                                                46
# 284     s285  TV Show                                   Abnormal Summit
# 578     s579  TV Show                      Ari Shaffir: Double Negative
# 1186   s1187  TV Show                                 Camelia la Texana
# 1629   s1630  TV Show                                    Dave Chappelle
# 1630   s1631  TV Show  Dave Chappelle: Equanimity & The Bird Revelation
# 1687   s1688  TV Show                              Degrassi: Next Class
# 2196   s2197  TV Show                                    Five Came Back
# 2380   s2381  TV Show                                  Geronimo Stilton
# 2439   s2440  TV Show                           Glitter Force Doki Doki
# 2474   s2475  TV Show                                             Gonul
# 2764   s2765  TV Show                                   Hoff the Record
# ...

# %% [markdown]
# ### 6. Show only title of all tv shows released in USA...

# %%
netflix[(netflix['Category']=='TV Show') & (netflix['Country']== 'United States')] ['Title']
# Out:
# 578                          Ari Shaffir: Double Negative
# 584                                                 Arrow
# 1470                     Comedians in Cars Getting Coffee
# 1629                                       Dave Chappelle
# 1630     Dave Chappelle: Equanimity & The Bird Revelation
# 1647                             DC's Legends of Tomorrow
# 1981                           Ellen DeGeneres: Relatable
# 2196                                       Five Came Back
# 2360                        Garth Brooks: The Road I’m On
# 2504                                               Gotham
# 2697                                        Hemlock Grove
# 2832                                       House of Cards
# 3238                               Julie and the Phantoms
# 3334                             Ken Burns: The Civil War
# 3951                                                 Mars
# 4055                      Metallica: Some Kind of Monster
# ...

# %% [markdown]
# ### 7. Show top director , who gave the highest number of Tv Shows & movies...

# %%
netflix['Director'].value_counts()
# Out:
# Raúl Campos, Jan Suter          18
# Marcus Raboy                    15
# Jay Karas                       14
# Cathy Garcia-Molina             13
# Jay Chapman                     12
#                                 ..
# Dustin McKenzie, Steve Sacks     1
# J.F. Musial, Josh Vietze         1
# James Franco                     1
# Takashi Doscher                  1
# Vinil Mathew                     1
# Name: Director, Length: 3614, dtype: int64

# %% [markdown]
# ### 8. Show all the records where category Movies and type is commedy or country united kingdom...

# %%
netflix[(netflix['Category']=='Movie') & (netflix['Type']== 'Comedies')]
# Out:
#      Show_Id Category                        Title                Director  \
# 33       s34    Movie                 #realityhigh        Fernando Lebrija
# 72       s73    Movie                     17 Again             Burr Steers
# 84       s85    Movie                    21 & Over  Jon Lucas, Scott Moore
# 148     s149    Movie         A Bad Moms Christmas  Jon Lucas, Scott Moore
# 174     s175    Movie  A Futile and Stupid Gesture              David Wain
# ...      ...      ...                          ...                     ...
# 7341   s7340    Movie         Undercover Brother 2            Leslie Small
# 7590   s7589    Movie            Where's the Money         Scott Zabielski
# 7623   s7622    Movie                    Wild Oats            Andy Tennant
# 7634   s7633    Movie                 Wine Country             Amy Poehler
# 7664   s7663    Movie                      Work It           Laura Terruso
#
#                                                    Cast  \
# ...

# %%
netflix[(netflix['Category']=='Movie') & (netflix['Type']== 'Comedies') | (netflix['Country']== 'United Kingdom')]
# Out:
#      Show_Id Category                       Title  \
# 33       s34    Movie                #realityhigh
# 72       s73    Movie                    17 Again
# 82       s83    Movie         2036 Origin Unknown
# 84       s85    Movie                   21 & Over
# 93       s94    Movie           27: Gone Too Soon
# ...      ...      ...                         ...
# 7615   s7614    Movie  Why Are We Getting So Fat?
# 7623   s7622    Movie                   Wild Oats
# 7634   s7633    Movie                Wine Country
# 7664   s7663    Movie                     Work It
# 7725   s7724    Movie                You Can Tutu
#
#                                     Director  \
# 33                          Fernando Lebrija
# 72                               Burr Steers
# 82                             Hasraf Dulull
# 84                    Jon Lucas, Scott Moore
# 93                         Simon Napier-Bell
# ...                                      ...
# ...

# %%
netflix['Cast'].value_counts()
# Out:
# Samuel West                                                                                                                                                 10
# Jeff Dunham                                                                                                                                                  7
# Kevin Hart                                                                                                                                                   6
# Bill Burr                                                                                                                                                    5
# Jim Gaffigan                                                                                                                                                 5
#                                                                                                                                                             ..
# ...

# %% [markdown]
# ### 9. In How many Tv show or movies tom cruise cast...

# %%
netflix[netflix['Cast'].str.contains('Tom Cruise')]
# Out:
#      Show_Id Category     Title              Director  \
# 3860   s3861    Movie  Magnolia  Paul Thomas Anderson
# 5071   s5071    Movie  Rain Man        Barry Levinson
#
#                                                    Cast        Country  \
# 3860  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
# 5071  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#          Release_Date Rating Duration                        Type  \
# 3860  January 1, 2020      R  189 min  Dramas, Independent Movies
# 5071     July 1, 2019      R  134 min      Classic Movies, Dramas
#
#                                             Description       Date  Year
# 3860  Through chance, human action, past history and... 2020-01-01  2020
# 5071  A fast-talking yuppie is forced to slow down w... 2019-07-01  2019

# %% [markdown]
# ### 10. What are different ratings in Netflix...

# %%
netflix['Rating'].unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-G', 'TV-PG', 'NR', 'PG', 'G',
#        'TV-Y7', 'TV-Y', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %%
netflix['Rating'].nunique()
# Out:
# 14

# %% [markdown]
# ### 11.(a) How many movies got Tv-14 ratings in Canada...

# %%
netflix[(netflix['Category']=='Movie') & (netflix['Rating']== 'TV-14') & (netflix['Country']=='Canada')]
# Out:
#      Show_Id Category                                        Title  \
# 34       s35    Movie                                        #Roxy
# 608     s609    Movie                               At First Light
# 1506   s1507    Movie                   Counterfeiting in Suburbia
# 3713   s3714    Movie                            Long Time Running
# 3956   s3957    Movie  Martin Matte: La vie, la mort...eh la la..!
# 5336   s5336    Movie                   Sadie's Last Days on Earth
# 5393   s5393    Movie                                   Sardaar ji
# 7025   s7024    Movie                         The Wrong Babysitter
# 7041   s7040    Movie               There's Something in the Water
#
#                                     Director  \
# 34                           Michael Kennedy
# 608                              Jason Stone
# 1506                           Jason Bourque
# 3713  Jennifer Baichwal, Nicholas de Pencier
# 3956                     Jean-François Blais
# ...

# %% [markdown]
# ### 11.(b) How many movies got R ratings after2018...¶

# %%
netflix[(netflix['Category']=='Movie') & (netflix['Rating']== 'TV-14') & (netflix['Year'] >=2018)]
# Out:
#      Show_Id Category                     Title            Director  \
# 8         s9    Movie                       706       Shravan Kumar
# 15       s16    Movie                    Oct-01      Kunle Afolayan
# 18       s19    Movie                    15-Aug  Swapnaneel Jayakar
# 20       s21    Movie      ​​Kuch Bheege Alfaaz                Onir
# 21       s22    Movie              ​Goli Soda 2        Vijay Milton
# ...      ...      ...                       ...                 ...
# 7765   s7764    Movie                     Zenda      Avadhoot Gupte
# 7766   s7765    Movie                      Zero          Aanand Rai
# 7770   s7769    Movie  Zindagi Kitni Haseen Hay       Anjum Shahzad
# 7771   s7770    Movie  Zindagi Na Milegi Dobara         Zoya Akhtar
# 7785   s7784    Movie                    Zubaan         Mozez Singh
#
#                                                    Cast   Country  \
# 8     Divya Dutta, Atul Kulkarni, Mohan Agashe, Anup...     India
# ...

# %% [markdown]
# ### 11(b). What is the max duation...

# %%
netflix['Duration'].max()
# Out:
# '99 min'

# %%
netflix['Duration'].min()
# Out:
# '1 Season'

# %%
netflix[['Minutes','Unit']] = netflix['Duration'].str.split(' ', expand = True)

# %%
netflix
# Out:
#      Show_Id Category       Title           Director  \
# 1         s2    Movie       07:19  Jorge Michel Grau
# 2         s3    Movie       23:59       Gilbert Chan
# 3         s4    Movie           9        Shane Acker
# 4         s5    Movie          21     Robert Luketic
# 5         s6  TV Show          46        Serdar Akar
# ...      ...      ...         ...                ...
# 7780   s7779    Movie  Zombieland    Ruben Fleischer
# 7782   s7781    Movie         Zoo       Shlok Sharma
# 7783   s7782    Movie        Zoom       Peter Hewitt
# 7784   s7783    Movie        Zozo        Josef Fares
# 7785   s7784    Movie      Zubaan        Mozez Singh
#
#                                                    Cast  \
# 1     Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 2     Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 3     Elijah Wood, John C. Reilly, Jennifer Connelly...
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...

# %%
netflix['Minutes']= netflix['Minutes'].astype(int) # casting the minutes

# %%
netflix['Minutes'].dtype
# Out:
# dtype('int32')

# %%
netflix['Minutes'].max()
# Out:
# 253

# %% [markdown]
# ### 12. Which Country has highest number of Tv shows

# %%
netflix_tvshwos = netflix[netflix['Category']=='TV Show']

# %%
netflix_tvshwos.Country.value_counts()
# Out:
# United States                                                    27
# United Kingdom                                                   19
# South Korea                                                      10
# Japan                                                            10
# Spain                                                             7
# Taiwan                                                            6
# India                                                             5
# Turkey                                                            5
# Brazil                                                            4
# Canada                                                            3
# Thailand                                                          3
# France                                                            3
# Nigeria                                                           3
# China                                                             2
# ...

# %%
sns.relplot(x = 'Title', y = 'Duration', data = netflix)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 48152 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 46300 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 51105 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 45716 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...
