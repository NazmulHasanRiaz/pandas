# %%
import pandas as pd
import seaborn as sns

# %%
alco = r'C:\Users\Riaz\Desktop\pandas\world_alcohol.csv'
alco = pd.read_csv(alco)
alco
# Out:
#     Year       WHO region                                Country  \
# 0   1986  Western Pacific                               Viet Nam
# 1   1986         Americas                                Uruguay
# 2   1985           Africa                           Cte d'Ivoire
# 3   1986         Americas                               Colombia
# 4   1987         Americas                  Saint Kitts and Nevis
# ..   ...              ...                                    ...
# 95  1984           Africa                                  Niger
# 96  1985           Europe                             Luxembourg
# 97  1984  South-East Asia                              Indonesia
# 98  1984           Africa                      Equatorial Guinea
# 99  1985  South-East Asia  Democratic People's Republic of Korea
#
#    Beverage Types  Display Value
# 0            Wine           0.00
# 1           Other           0.50
# 2            Wine           1.62
# 3            Beer           4.27
# ...

# %% [markdown]
# ### 1. Display the dimensions or shape of the World alcohol consumption dataset. Also extract the column names from the datase

# %%
alco.shape
# Out:
# (100, 5)

# %%
alco.columns
# Out:
# Index(['Year', 'WHO region', 'Country', 'Beverage Types', 'Display Value'], dtype='object')

# %% [markdown]
# ### 2. Select first 2 rows, 2 columns and specific two columns from World alcohol consumption dataset.

# %%
# getting first two rows...
alco.loc[0:1,:]
# Out:
#    Year       WHO region   Country Beverage Types  Display Value
# 0  1986  Western Pacific  Viet Nam           Wine            0.0
# 1  1986         Americas   Uruguay          Other            0.5

# %%
# getting first two col...
alco[['Year','WHO region']].head()
# Out:
#    Year       WHO region
# 0  1986  Western Pacific
# 1  1986         Americas
# 2  1985           Africa
# 3  1986         Americas
# 4  1987         Americas

# %% [markdown]
# ### 4. find and drop the missing values from World alcohol consumption dataset|

# %%
alco.isnull().sum()
# Out:
# Year              0
# WHO region        0
# Country           0
# Beverage Types    0
# Display Value     5
# dtype: int64

# %%
# how = 'any' drop any missing value in df..
# how = 'all' drop the df if all values are null...

alco.dropna(how = 'any',inplace = True)

# %%
alco
# Out:
#     Year       WHO region                                Country  \
# 0   1986  Western Pacific                               Viet Nam
# 1   1986         Americas                                Uruguay
# 2   1985           Africa                           Cte d'Ivoire
# 3   1986         Americas                               Colombia
# 4   1987         Americas                  Saint Kitts and Nevis
# ..   ...              ...                                    ...
# 95  1984           Africa                                  Niger
# 96  1985           Europe                             Luxembourg
# 97  1984  South-East Asia                              Indonesia
# 98  1984           Africa                      Equatorial Guinea
# 99  1985  South-East Asia  Democratic People's Republic of Korea
#
#    Beverage Types  Display Value
# 0            Wine           0.00
# 1           Other           0.50
# 2            Wine           1.62
# 3            Beer           4.27
# ...

# %% [markdown]
# ### 5. remove the duplicates from 'WHO region' column of World alcohol consumption dataset

# %%
alco.drop_duplicates(subset='WHO region', keep='first', inplace=True)
alco
# Out:
#     Year             WHO region       Country Beverage Types  Display Value
# 0   1986        Western Pacific      Viet Nam           Wine           0.00
# 1   1986               Americas       Uruguay          Other           0.50
# 2   1985                 Africa  Cte d'Ivoire           Wine           1.62
# 13  1984  Eastern Mediterranean   Afghanistan          Other           0.00
# 18  1984                 Europe        Norway        Spirits           1.62
# 20  1986        South-East Asia       Myanmar           Wine           0.00

# %% [markdown]
# ### 6. find out the alcohol consumption of a given year from the world alcohol consumption dataset.

# %%
alco['Year'].dtype
# Out:
# dtype('int64')

# %%
alco[alco.Year == 1984]
# Out:
#     Year             WHO region      Country Beverage Types  Display Value
# 13  1984  Eastern Mediterranean  Afghanistan          Other           0.00
# 18  1984                 Europe       Norway        Spirits           1.62

# %%
import pandas as pd

# %%
alco_1 = r'C:\Users\Riaz\Desktop\pandas\world_alcohol.csv'
alco_1 = pd.read_csv(alco_1)
alco_1
# Out:
#     Year       WHO region                                Country  \
# 0   1986  Western Pacific                               Viet Nam
# 1   1986         Americas                                Uruguay
# 2   1985           Africa                           Cte d'Ivoire
# 3   1986         Americas                               Colombia
# 4   1987         Americas                  Saint Kitts and Nevis
# ..   ...              ...                                    ...
# 95  1984           Africa                                  Niger
# 96  1985           Europe                             Luxembourg
# 97  1984  South-East Asia                              Indonesia
# 98  1984           Africa                      Equatorial Guinea
# 99  1985  South-East Asia  Democratic People's Republic of Korea
#
#    Beverage Types  Display Value
# 0            Wine           0.00
# 1           Other           0.50
# 2            Wine           1.62
# 3            Beer           4.27
# ...

# %%
alco_1[alco_1.Year == 1985]
# Out:
#     Year             WHO region  \
# 2   1985                 Africa
# 7   1985                 Africa
# 12  1985        Western Pacific
# 14  1985        Western Pacific
# 24  1985                 Africa
# 26  1985                 Europe
# 33  1985                 Africa
# 35  1985               Americas
# 44  1985                 Europe
# 50  1985                 Europe
# 63  1985  Eastern Mediterranean
# 71  1985                 Africa
# 76  1985                 Africa
# 77  1985                 Africa
# 80  1985                 Africa
# 81  1985                 Europe
# 85  1985                 Africa
# 94  1985                 Europe
# 96  1985                 Europe
# 99  1985        South-East Asia
#
#                                               Country Beverage Types  \
# 2                                        Cte d'Ivoire           Wine
# 7                                              Angola        Spirits
# ...

# %% [markdown]
# ### 8. find out the alcohol consumption details by the 'Americas' in the year '1985' from the world alcohol consumption dataset.

# %%
alco_1[(alco_1['Year'] == 1985) & (alco_1['WHO region']=='Americas')]
# Out:
#     Year WHO region                Country Beverage Types  Display Value
# 35  1985   Americas  Saint Kitts and Nevis        Spirits           2.24

# %% [markdown]
# ### 9. find out the alcohol consumption details in the year '1986' where WHO region is 'Western Pacific' and country is 'VietNam' from the world alcohol consumption dataset

# %%
alco_1[(alco_1['Year'] == 1986) & (alco_1['Country'] =='Viet Nam') & (alco_1['WHO region']=='Western Pacific')]
# Out:
#    Year       WHO region   Country Beverage Types  Display Value
# 0  1986  Western Pacific  Viet Nam           Wine            0.0

# %% [markdown]
# ### find out the records where consumption of beverages per person average >=5 and Beverage Types is Beer from world alcohol consumption dataset

# %%
alco_1[(alco_1['Beverage Types'] == 'Beer') & (alco_1['Display Value'] >=5)]
# Out:
#     Year WHO region         Country Beverage Types  Display Value
# 41  1986     Europe  Czech Republic           Beer           6.82

# %% [markdown]
# ### filter the specified columns and records by range from world alcohol consumption dataset

# %%
alco_1[['WHO region','Beverage Types']].head()
# Out:
#         WHO region Beverage Types
# 0  Western Pacific           Wine
# 1         Americas          Other
# 2           Africa           Wine
# 3         Americas           Beer
# 4         Americas           Beer

# %% [markdown]
# ### filter those records where WHO region contains "Ea" substring from world alcohol consumption dataset

# %%
alco_1[alco_1['WHO region'].str.contains('Ea')]
# Out:
#     Year             WHO region                                Country  \
# 13  1984  Eastern Mediterranean                            Afghanistan
# 20  1986        South-East Asia                                Myanmar
# 25  1984  Eastern Mediterranean                                Tunisia
# 27  1984  Eastern Mediterranean                                Bahrain
# 36  1987  Eastern Mediterranean                                  Egypt
# 38  1987  Eastern Mediterranean                                  Qatar
# 52  1986  Eastern Mediterranean                           Saudi Arabia
# 53  1984  Eastern Mediterranean                                 Kuwait
# 58  1984  Eastern Mediterranean                                Somalia
# 59  1989  Eastern Mediterranean                   Syrian Arab Republic
# 60  1987  Eastern Mediterranean             Iran (Islamic Republic of)
# 63  1985  Eastern Mediterranean                                  Libya
# ...

# %% [markdown]
# ### filter all records where the average consumption of beverages per person from .5 to 2.50 in world alcohol consumption dataset

# %%
alco_1[(alco_1['Display Value']>=.5) & (alco_1['Display Value'] <= 2.5)]
# Out:
#     Year             WHO region  \
# 1   1986               Americas
# 2   1985                 Africa
# 4   1987               Americas
# 8   1986               Americas
# 11  1989               Americas
# 17  1989                 Africa
# 18  1984                 Europe
# 19  1984                 Africa
# 26  1985                 Europe
# 27  1984  Eastern Mediterranean
# 32  1989                 Africa
# 34  1986                 Europe
# 35  1985               Americas
# 40  1987                 Europe
# 46  1987               Americas
# 48  1987               Americas
# 49  1986                 Europe
# 54  1984               Americas
# 64  1989               Americas
# 70  1986                 Africa
# 71  1985                 Africa
# 74  1986               Americas
# 79  1989                 Europe
# 80  1985                 Africa
# 82  1987                 Europe
# 86  1986               Americas
# 89  1986  Eastern Mediterranean
#
# ...

# %% [markdown]
# ### find average consumption of wine per person greater than 2 in world alcohol consumption dataset

# %%
alco_1[(alco_1['Beverage Types']== 'Wine') & (alco_1['Display Value'] > 2.0)]
# Out:
#     Year WHO region      Country Beverage Types  Display Value
# 57  1989     Europe      Croatia           Wine           5.10
# 81  1985     Europe  Netherlands           Wine           2.54
# 96  1985     Europe   Luxembourg           Wine           7.38

# %% [markdown]
# ### filter all records starting from the 2nd row, access every 5th row from world alcohol consumption dataset.

# %%
alco_1 = alco_1.iloc[1:50:5]

# %%
alco_1
# Out:
#     Year             WHO region  \
# 1   1986               Americas
# 6   1987                 Africa
# 11  1989               Americas
# 16  1984               Americas
# 21  1989               Americas
# 26  1985                 Europe
# 31  1986        Western Pacific
# 36  1987  Eastern Mediterranean
# 41  1986                 Europe
# 46  1987               Americas
#
#                                               Country Beverage Types  \
# 1                                             Uruguay          Other
# 6                                           Mauritius           Wine
# 11                                          Guatemala           Beer
# 16                                         Costa Rica           Wine
# 21                                         Costa Rica        Spirits
# 26  United Kingdom of Great Britain and Northern I...           Wine
# 31                   Micronesia (Federated States of)           Wine
# ...

# %%
import seaborn as sns

# %%
alco_1['WHO region'].value_counts()
# Out:
# Americas                 5
# Europe                   2
# Eastern Mediterranean    1
# Africa                   1
# Western Pacific          1
# Name: WHO region, dtype: int64

# %%
alco_1['Beverage Types'].value_counts()
# Out:
# Wine       4
# Beer       3
# Spirits    2
# Other      1
# Name: Beverage Types, dtype: int64

# %%
alco_1['WHO region'].value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
alco_1['Beverage Types'].value_counts().plot(kind = 'pie')
# Out:
# <AxesSubplot:ylabel='Beverage Types'>

# %%
sns.relplot(x = 'Year', y = 'Display Value', hue = 'Beverage Types', data = alco_1, kind = )
